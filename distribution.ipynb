# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib.pyplot as plt
import torch.nn as nn
import torch

from jaxtyping import Float
from data.chess import ChessDataset
from data.gaussian import GaussianDistribution

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
torch.set_default_device(device)

# %%
class FourierEmbedding(nn.Module):
    def __init__(self, num_freqs: int = 6, channels: int = 2):
        super().__init__()
        self.num_freqs = num_freqs
        self.channels = channels
        self.out_dim = 2 * num_freqs * channels
        
        freq_bands = 2.0 ** torch.linspace(0, num_freqs-1, num_freqs)
        self.register_buffer('freq_bands', freq_bands)
    
    def forward(self, X):
        result = []

        for freq in self.freq_bands:
            for c in range(self.channels):
                result.append(torch.sin(X[:, c] * freq * torch.pi).unsqueeze(-1))
                result.append(torch.cos(X[:, c] * freq * torch.pi).unsqueeze(-1))
        
        return torch.cat(result, dim=-1)

# %%
class FlowMatching(nn.Module):
    def __init__(
        self,
        in_features: int,
        time_freq: int = 4,
        feature_freq: int = 10,
        hidden_layers: int = 8,
        hidden_features: int = 512,
        activation: str = "ReLU",
        bias: bool = True,
    ):
        assert activation in [
            "ReLU",
            "Tanh",
            "GELU",
            "SiLU",
            "Mish",
        ], "Inappropriate activation function chosen."

        super().__init__()
        self.in_features = in_features
        self.out_features = in_features
        self.hidden_layers = hidden_layers
        self.hidden_features = hidden_features
        self.activation = activation
        self.bias = bias

        self.feature_embed = FourierEmbedding(num_freqs=feature_freq, channels=self.in_features)
        self.time_embed = FourierEmbedding(num_freqs=time_freq, channels=1)
        self.net = self.initialize_net()

    def initialize_net(self):
        net = []

        net.extend(
            [
                nn.Linear(
                    in_features=self.feature_embed.out_dim + self.time_embed.out_dim,
                    out_features=self.hidden_features,
                    bias=self.bias,
                ),
                nn.BatchNorm1d(self.hidden_features),
                getattr(nn, self.activation)(),
            ]
        )

        for i in range(self.hidden_layers):
            net.extend(
                [
                    nn.Linear(
                        in_features=self.hidden_features,
                        out_features=self.hidden_features,
                        bias=self.bias,
                    ),
                    nn.BatchNorm1d(self.hidden_features),
                    getattr(nn, self.activation)(),
                    nn.Dropout(p=0.1 + (0.4 / self.hidden_layers) * i),
                ]
            )

        net.extend(
            [
                nn.Linear(
                    in_features=self.hidden_features,
                    out_features=self.hidden_features // 2,
                    bias=self.bias,
                ),
                getattr(nn, self.activation)(),
                nn.Linear(
                    in_features=self.hidden_features // 2,
                    out_features=self.out_features,
                    bias=self.bias,
                ),
            ]
        )

        return nn.Sequential(*net)

    def forward(
        self,
        X: Float[torch.Tensor, "*batch dim"],
        T: Float[torch.Tensor, "*batch 1"],
    ) -> Float[torch.Tensor, "*batch dim"]:
        X_embed = self.feature_embed(X)
        T_embed = self.time_embed(T)
        return self.net(torch.cat((X_embed, T_embed), dim=-1))

# %%
def training(
    model: FlowMatching,
    dataset_size: int = 2**14,
    batch_size: int = 64,
    lr: float = 1e-4,
    epochs: int = 10,
):
    optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=1e-6)
    gaussian = GaussianDistribution(
        mean=torch.tensor([0, 0], dtype=torch.float32),
        std=torch.tensor([1, 1], dtype=torch.float32),
    )

    training_set = ChessDataset(
        size=dataset_size, batch_size=batch_size, num_squares=4, num_range=3.75
    )
    validation_set = ChessDataset(
        size=2048, batch_size=256, num_squares=4, num_range=3.75
    )

    losses = []
    for e in range(epochs):
        model.train()
        training_loss = 0.0
        for i in range(dataset_size // batch_size):
            Z = training_set.get_batch(i)
            T = torch.rand(batch_size).unsqueeze(-1)
            epsilon = gaussian.sample(batch_size)

            X = T * Z + (1 - T) * epsilon
            target = Z - epsilon

            out = model(X, T)
            loss = torch.nn.functional.mse_loss(out, target)
            training_loss += loss.item()

            optimizer.zero_grad()
            loss.backward()

            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

        model.eval()
        validation_loss = 0.0
        with torch.no_grad():
            for i in range(8):
                Z = validation_set.get_batch(i)
                T = torch.rand(256).unsqueeze(-1)
                epsilon = gaussian.sample(256)

                X = T * Z + (1 - T) * epsilon
                target = Z - epsilon

                out = model(X, T)
                loss = torch.nn.functional.mse_loss(out, target)
                validation_loss += loss.item()

        training_loss /= (dataset_size // batch_size)
        validation_loss /= 8.0
        
        losses.append(training_loss)
        print(f"Epoch {e}; : validation loss={validation_loss:.4f}, training loss={training_loss:.4f}")
        
    return losses

# %%
params = {
    "in_features": 2,
    "time_freq": 8,
    "feature_freq": 12,
    "hidden_layers": 8,
    "hidden_features": 1024,
    "activation": "ReLU",
    "bias": True,
}
flow_matching_model = FlowMatching(**params).to(device=device)
print(f"Total Model Parameters: ~{sum(p.numel() for p in flow_matching_model.parameters()) // 1e6}mil")

losses = training(model=flow_matching_model, dataset_size=2**14, batch_size=512, lr=3e-4, epochs=100)
fig, ax = plt.subplots()
ax.plot(losses)
ax.set_xlabel('Epochs')
ax.set_ylabel('Training Loss')
ax.set_yscale('log')

fig.show(warn=False)
# Out:
# Total Model Parameters: ~9.0mil
# Epoch 0; : validation loss=2.1047, training loss=2.1910
# Epoch 1; : validation loss=2.1060, training loss=2.2220
# Epoch 2; : validation loss=2.2150, training loss=2.1747
# Epoch 3; : validation loss=2.1731, training loss=2.1896
# Epoch 4; : validation loss=2.1577, training loss=2.1525
# Epoch 5; : validation loss=2.1092, training loss=2.1462
# Epoch 6; : validation loss=2.1080, training loss=2.1370
# Epoch 7; : validation loss=2.0848, training loss=2.1083
# Epoch 8; : validation loss=2.1481, training loss=2.1227
# Epoch 9; : validation loss=2.0397, training loss=2.0898
# Epoch 10; : validation loss=2.0530, training loss=2.0927
# Epoch 11; : validation loss=2.0562, training loss=2.0828
# Epoch 12; : validation loss=2.0258, training loss=2.0943
# Epoch 13; : validation loss=2.0637, training loss=2.0814
# Epoch 14; : validation loss=2.1054, training loss=2.0748
# Epoch 15; : validation loss=2.1096, training loss=2.0815
# Epoch 16; : validation loss=2.1076, training loss=2.0753
# Epoch 17; : validation loss=2.0233, training loss=2.0686
# Epoch 18; : validation loss=2.0859, training loss=2.0761
# Epoch 19; : validation loss=2.0336, training loss=2.0678
# Epoch 20; : validation loss=2.0387, training loss=2.0970
# Epoch 21; : validation loss=2.0545, training loss=2.0570
# Epoch 22; : validation loss=2.0201, training loss=2.0582
# Epoch 23; : validation loss=2.0387, training loss=2.0524
# Epoch 24; : validation loss=2.0918, training loss=2.0457
# Epoch 25; : validation loss=2.0201, training loss=2.0795
# Epoch 26; : validation loss=2.0356, training loss=2.0712
# Epoch 27; : validation loss=2.0210, training loss=2.0633
# Epoch 28; : validation loss=2.1016, training loss=2.0389
# Epoch 29; : validation loss=2.0356, training loss=2.0772
# Epoch 30; : validation loss=2.1143, training loss=2.0439
# Epoch 31; : validation loss=2.0237, training loss=2.0732
# Epoch 32; : validation loss=2.0956, training loss=2.0857
# Epoch 33; : validation loss=2.0544, training loss=2.0752
# Epoch 34; : validation loss=2.0529, training loss=2.0633
# Epoch 35; : validation loss=2.0396, training loss=2.0712
# Epoch 36; : validation loss=2.1264, training loss=2.0506
# Epoch 37; : validation loss=1.9870, training loss=2.0710
# Epoch 38; : validation loss=2.0692, training loss=2.0556
# Epoch 39; : validation loss=1.9862, training loss=2.0734
# Epoch 40; : validation loss=1.9925, training loss=2.0844
# Epoch 41; : validation loss=2.0467, training loss=2.0436
# Epoch 42; : validation loss=2.0365, training loss=2.0670
# Epoch 43; : validation loss=2.0266, training loss=2.0749
# Epoch 44; : validation loss=2.0783, training loss=2.0852
# Epoch 45; : validation loss=2.0166, training loss=2.0665
# Epoch 46; : validation loss=2.0034, training loss=2.0795
# Epoch 47; : validation loss=2.0625, training loss=2.0441
# Epoch 48; : validation loss=2.1128, training loss=2.0442
# Epoch 49; : validation loss=1.9571, training loss=2.0451
# Epoch 50; : validation loss=2.0944, training loss=2.0465
# Epoch 51; : validation loss=2.0711, training loss=2.0624
# Epoch 52; : validation loss=2.0050, training loss=2.0376
# Epoch 53; : validation loss=2.0943, training loss=2.0557
# Epoch 54; : validation loss=2.1003, training loss=2.0671
# Epoch 55; : validation loss=2.0275, training loss=2.0219
# Epoch 56; : validation loss=1.9943, training loss=2.0582
# Epoch 57; : validation loss=2.0629, training loss=2.0701
# Epoch 58; : validation loss=2.0476, training loss=2.0583
# Epoch 59; : validation loss=2.0187, training loss=2.0686
# Epoch 60; : validation loss=2.0238, training loss=2.0556
# Epoch 61; : validation loss=1.9939, training loss=2.0218
# Epoch 62; : validation loss=1.9732, training loss=2.0755
# Epoch 63; : validation loss=2.0429, training loss=2.0613
# Epoch 64; : validation loss=2.0348, training loss=2.0396
# Epoch 65; : validation loss=1.9732, training loss=2.0816
# Epoch 66; : validation loss=2.0675, training loss=2.0286
# Epoch 67; : validation loss=2.0708, training loss=2.0698
# Epoch 68; : validation loss=2.0535, training loss=2.0628
# Epoch 69; : validation loss=1.9837, training loss=2.0537
# Epoch 70; : validation loss=1.9977, training loss=2.0539
# Epoch 71; : validation loss=2.0051, training loss=2.0541
# Epoch 72; : validation loss=2.0560, training loss=2.0310
# Epoch 73; : validation loss=1.9999, training loss=2.0696
# Epoch 74; : validation loss=2.0426, training loss=2.0652
# Epoch 75; : validation loss=2.0840, training loss=2.0491
# Epoch 76; : validation loss=2.0838, training loss=2.0390
# Epoch 77; : validation loss=2.0019, training loss=2.0330
# Epoch 78; : validation loss=2.0191, training loss=2.0512
# Epoch 79; : validation loss=2.0598, training loss=2.0353
# Epoch 80; : validation loss=2.0094, training loss=2.0456
# Epoch 81; : validation loss=2.0449, training loss=2.0588
# Epoch 82; : validation loss=1.9514, training loss=2.0528
# Epoch 83; : validation loss=2.0710, training loss=2.0661
# Epoch 84; : validation loss=2.0348, training loss=2.0651
# Epoch 85; : validation loss=2.0456, training loss=2.0338
# Epoch 86; : validation loss=1.9731, training loss=2.0749
# Epoch 87; : validation loss=2.0611, training loss=2.0463
# Epoch 88; : validation loss=2.0398, training loss=2.0563
# Epoch 89; : validation loss=2.1273, training loss=2.0374
# Epoch 90; : validation loss=2.0543, training loss=2.0576
# Epoch 91; : validation loss=2.0710, training loss=2.0574
# Epoch 92; : validation loss=2.0143, training loss=2.0449
# Epoch 93; : validation loss=2.0943, training loss=2.0697
# Epoch 94; : validation loss=2.0685, training loss=2.0381
# Epoch 95; : validation loss=2.1033, training loss=2.0424
# Epoch 96; : validation loss=2.0175, training loss=2.0594
# Epoch 97; : validation loss=2.0282, training loss=2.0341
# Epoch 98; : validation loss=2.0966, training loss=2.0451
# Epoch 99; : validation loss=2.0424, training loss=2.0516

# %%
n_steps = 200
samples = 8000
dt = 1/n_steps

X = GaussianDistribution(
    mean=torch.tensor([0, 0], dtype=torch.float32),
    std=torch.tensor([1, 1], dtype=torch.float32),
).sample(samples)

flow_matching_model.eval()
with torch.no_grad():
    for i in range(n_steps):
        T = torch.ones(samples, 1, device=device) * (i * dt)
        U = flow_matching_model(X, T)
        
        X = X + dt * U

        if (i+1) % (n_steps//4) == 0:
            out = X.detach().cpu().numpy()
            fig, ax = plt.subplots()
            ax.hist2d(out[:, 0], out[:, 1], bins=150)
            fig.show(warn=False)

# %%
version = 1
torch.save(flow_matching_model.state_dict(), f'outputs/flow_matching_model_v{version}.pt')
torch.save(params, f'outputs/flow_matching_model_params_v{version}.pt')
